# %% [markdown]
# <a href="https://colab.research.google.com/github/m-hossni/Tensorflow-and-Keras-INFO-6146-F24/blob/main/Usman_double_layered_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input, Flatten, Dropout
from tensorflow.keras.datasets import fashion_mnist

(train_images, train_labels), (test_images, test_labels)= fashion_mnist.load_data()

x_train = train_images.reshape(-1, 28 * 28) / 255.0
x_test = test_images.reshape(-1, 28 * 28) / 255.0

# %%
x_train.shape
# Out:
# (60000, 784)

# %%
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(28*28,) ))
Dropout(0.2),
model.add(Dense(128, activation='relu' ))
Dropout(0.2),
model.add(Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history = model.fit(x_train,train_labels, batch_size=64, shuffle=True,  epochs=25, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.7641 - loss: 0.6934 - val_accuracy: 0.8405 - val_loss: 0.4437
# Epoch 2/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8597 - loss: 0.3909 - val_accuracy: 0.8683 - val_loss: 0.3622
# Epoch 3/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8686 - loss: 0.3547 - val_accuracy: 0.8651 - val_loss: 0.3647
# Epoch 4/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8843 - loss: 0.3136 - val_accuracy: 0.8741 - val_loss: 0.3425
# Epoch 5/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8900 - loss: 0.2964 - val_accuracy: 0.8830 - val_loss: 0.3245
# Epoch 6/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8952 - loss: 0.2833 - val_accuracy: 0.8826 - val_loss: 0.3279
# Epoch 7/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.8969 - loss: 0.2731 - val_accuracy: 0.8747 - val_loss: 0.3499
# Epoch 8/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9068 - loss: 0.2486 - val_accuracy: 0.8904 - val_loss: 0.3178
# Epoch 9/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9075 - loss: 0.2451 - val_accuracy: 0.8863 - val_loss: 0.3184
# Epoch 10/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9116 - loss: 0.2332 - val_accuracy: 0.8847 - val_loss: 0.3252
# Epoch 11/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9151 - loss: 0.2226 - val_accuracy: 0.8886 - val_loss: 0.3277
# Epoch 12/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9160 - loss: 0.2205 - val_accuracy: 0.8918 - val_loss: 0.3191
# Epoch 13/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9204 - loss: 0.2108 - val_accuracy: 0.8896 - val_loss: 0.3285
# Epoch 14/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9229 - loss: 0.2023 - val_accuracy: 0.8897 - val_loss: 0.3260
# Epoch 15/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9261 - loss: 0.1941 - val_accuracy: 0.8926 - val_loss: 0.3205
# Epoch 16/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9277 - loss: 0.1891 - val_accuracy: 0.8857 - val_loss: 0.3427
# Epoch 17/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9321 - loss: 0.1789 - val_accuracy: 0.8883 - val_loss: 0.3469
# Epoch 18/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9331 - loss: 0.1710 - val_accuracy: 0.8982 - val_loss: 0.3264
# Epoch 19/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9354 - loss: 0.1694 - val_accuracy: 0.8965 - val_loss: 0.3347
# Epoch 20/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9352 - loss: 0.1647 - val_accuracy: 0.8938 - val_loss: 0.3501
# Epoch 21/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9392 - loss: 0.1607 - val_accuracy: 0.8898 - val_loss: 0.3593
# Epoch 22/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9429 - loss: 0.1511 - val_accuracy: 0.8912 - val_loss: 0.3751
# Epoch 23/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9456 - loss: 0.1470 - val_accuracy: 0.8915 - val_loss: 0.3710
# Epoch 24/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9466 - loss: 0.1383 - val_accuracy: 0.8917 - val_loss: 0.3871
# Epoch 25/25
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9459 - loss: 0.1386 - val_accuracy: 0.8913 - val_loss: 0.3872

# %%
y_pred = model.predict(x_test)
y_pred = y_pred.argmax(axis=-1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
accuracy_score(test_labels,y_pred)
# Out:
# 0.8885

# %%
import matplotlib.pyplot as plt

# Class names for the Fashion MNIST dataset
class_names = [
    "T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
    "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
]

# Plot 25 images with their labels
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(test_images[i], cmap=plt.cm.binary)  # Display in grayscale
    label_color = 'green' if test_labels[i] == y_pred[i] else 'red'
    plt.xlabel(f"{class_names[test_labels[i]]} ({ class_names[y_pred[i]]})", color=label_color )  # Show true label
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
confusion_mtrx = confusion_matrix(y_true=test_labels, y_pred=y_pred)

# %%
  classes = {
    0:	'T-shirt/top',
    1:	'Trouser',
    2:	'Pullover',
    3:	'Dress',
    4:	'Coat',
    5:	'Sandal',
    6:	'Shirt',
    7:	'Sneaker',
    8:	'Bag',
    9:	'Ankle boot',
    }

# %%
import seaborn as sns
import numpy as np
fig = plt.figure(figsize=(20,7))
plt.subplot(1,2,1)
sns.heatmap(confusion_mtrx,xticklabels=[value for value in classes.values()], yticklabels=[value for value in classes.values()],annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix for Random Forest')
plt.subplot(1,2,2)
sns.barplot(x=[value for value in classes.values()], y=np.diag(confusion_mtrx))
plt.title('True Positives for Random Forest')
plt.ylabel('count of true positives')
plt.xlabel('classes')
plt.show()

# %%
import pandas as pd
conf_matrix = pd.DataFrame(confusion_mtrx)
conf_matrix.columns = [value for value in classes.values()]
conf_matrix.to_csv('CM_DLANN.csv')
